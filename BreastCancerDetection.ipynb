# %%
z
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /usr/local/lib/python3.7/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     728             try:
# --> 729                 ident, reply = self.session.recv(self.stdin_socket, 0)
#     730             except Exception:
#
# /usr/local/lib/python3.7/dist-packages/jupyter_client/session.py in recv(self, socket, mode, content, copy)
#     802         try:
# --> 803             msg_list = socket.recv_multipart(mode, copy=copy)
#     804         except zmq.ZMQError as e:
#
# /usr/local/lib/python3.7/dist-packages/zmq/sugar/socket.py in recv_multipart(self, flags, copy, track)
#     582         """
# --> 583         parts = [self.recv(flags, copy=copy, track=track)]
#     584         # have first part already, only loop while more to receive
#
# ...

# %%
#Here i am importing some necessary packages liberaries
import pandas as pd
import seaborn as sns
import datetime as dt
import numpy as np

# %% [markdown]
# #Dataset Exploration

# %%
#Here i am accessing the dataset file which covid.csv from my google drive
dataR2 = pd.read_csv('gdrive/MyDrive/BreastCancerDetection/dataR2.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-75e0b144022e> in <module>()
#       1 #Here i am accessing the dataset file which covid.csv from my google drive
# ----> 2 dataR2 = pd.read_csv('gdrive/MyDrive/BreastCancerDetection/dataR2.csv')
#
# NameError: name 'pd' is not defined

# %%
#Here I am showing only top 5 rows of our dataset
dataset.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-dd05eea9dfda> in <module>()
#       1 #Here I am showing only top 5 rows of our dataset
# ----> 2 dataset.head()
#
# NameError: name 'dataset' is not defined

# %%
#Looking at the shape
dataset.shape
# Out:
# (116, 10)

# %%
#Looking at columns
dataset.columns
# Out:
# Index(['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin',
#        'Resistin', 'MCP.1', 'Classification'],
#       dtype='object')

# %%
#Checking if columns have null values
dataset.isna().any()
# Out:
# Age               False
# BMI               False
# Glucose           False
# Insulin           False
# HOMA              False
# Leptin            False
# Adiponectin       False
# Resistin          False
# MCP.1             False
# Classification    False
# dtype: bool

# %%
#Getting the sum of null values across each column
dataset.isna().sum()
# Out:
# Age               0
# BMI               0
# Glucose           0
# Insulin           0
# HOMA              0
# Leptin            0
# Adiponectin       0
# Resistin          0
# MCP.1             0
# Classification    0
# dtype: int64

# %% [markdown]
# # Preparing dataset

# %%
#Getting the columns which will be used for features
X = dataset[['Age', 'BMI', 'Glucose', 'Insulin', 'HOMA', 'Leptin', 'Adiponectin', 'Resistin', 'MCP.1']]
#Getting the column which will be used as predictor
y = covid["Classification"]

# %%
# I am getting the train_test_split function for splitting my dateset into training and testing
from sklearn.model_selection import train_test_split

# %%
# I am splitting the dataset
x_train, x_test, y_train, y_test = train_test_split(X,y,test_size=0.05)

# %% [markdown]
# #Training Models

# %% [markdown]
# ## Model 1: Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression(solver='lbfgs', max_iter=4000)

# %%
logmodel.fit(x_train, y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=4000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=None, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)

# %%
y_pred = logmodel.predict(x_test)

# %%
y_pred
# Out:
# array([2, 1, 1, 2, 1, 1])

# %%
print("Accuracy: %d", (logmodel.score(x_test, y_test)))
# Out:
# Accuracy: %d 0.5

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix = confusion_matrix(y_test, y_pred)

# %%
print(confusion_matrix)
# Out:
# [[3 2]
#  [1 0]]

# %% [markdown]
# ## Model2: Decision Tree

# %%
# import the Decision Tree classifier
from sklearn.tree import DecisionTreeClassifier

# %%
# create a regressor object
dtClassifier = DecisionTreeClassifier(random_state = 0)

# %%
# fit the regressor with X and Y data
dtClassifier.fit(X, y)
# Out:
# DecisionTreeClassifier(ccp_alpha=0.0, class_weight=None, criterion='gini',
#                        max_depth=None, max_features=None, max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, presort='deprecated',
#                        random_state=0, splitter='best')

# %%
yPred = dtClassifier.predict(x_test)

# %%
yPred
# Out:
# array([1, 1, 2, 1, 1, 1])

# %%
print("Accuracy: %d", (dtClassifier.score(x_test, y_test)))
# Out:
# Accuracy: %d 1.0

# %%
from sklearn.metrics import confusion_matrix

# %%
confusion_matrix = confusion_matrix(y_test, yPred)

# %%
print(confusion_matrix)
# Out:
# [[5 0]
#  [0 1]]
